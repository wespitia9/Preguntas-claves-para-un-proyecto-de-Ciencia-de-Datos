# %% [markdown]
# <a href="https://colab.research.google.com/github/wespitia9/Preguntas-claves-para-un-proyecto-de-Ciencia-de-Datos/blob/main/Preguntas_claves_para_un_proyecto_de_Ciencia_de_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![data science.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Para que cualquier proyecto, de cualquier industria, de cualquier sector, tenga éxito, deben existir conexiones claras y concisas de las diferentes áreas de negocios y stakeholders; y esto no es ajeno para un proyecto de `Ciencia de Datos`.
#
# **¿El alcance de la lógica del negocio debe ser holístico?** El término "holístico" se refiere a la idea de que algo es más que la suma de sus partes individuales, y que debe ser considerado en su totalidad para comprender su verdadera naturaleza o esencia. En el contexto del alcance de negocios, "holístico" significa que se está considerando el negocio en su totalidad, en lugar de centrarse solo en partes o aspectos específicos del mismo.
#
# Esto implica que se está considerando la interacción y relación de diferentes áreas del negocio, como la estrategia, la operación, el marketing, la tecnología, el recurso humano, las finanzas, entre otras, para lograr una comprensión completa del negocio y sus necesidades.

# %% [markdown]
# El éxito de un proyecto de `Ciencia de Datos` depende de varios factores, pero tener un objetivo claro, recopilar `datos` de alta calidad, seleccionar las herramientas y tecnologías adecuadas, contar con un equipo interdisciplinario, realizar una exploración adecuada de los `datos`, asegurar la validez y precisión de los resultados, comunicar los resultados de manera efectiva y mantener un enfoque iterativo son algunos de los factores clave que pueden marcar la diferencia en el éxito del proyecto.
#
# Hay varios factores que pueden influir en el éxito de un proyecto de ciencia de `datos`, pero también hay preguntas claves que pueden marcar la diferencia positiva en el desarrollo de dicho proyecto.

# %% [markdown]
# # ¿Cuál es el objetivo de negocio de este proyecto?

# %% [markdown]
# La información de alto nivel proporciona un marco y una dirección para las tareas en todo el proyecto. Al comprender el propósito de una tarea, sabemos qué preguntas debemos plantear y a quién podemos recurrir para obtener respuestas. Este enfoque orienta nuestro pensamiento hacia soluciones efectivas y eficientes.

# %% [markdown]
# # ¿Se puede resilver o mejorar el proyecto con la aplicación de `Ciencia de Datos`?

# %% [markdown]
# La `Ciencia de Datos` puede mejorar muchos aspectos de un negocio, pero es importante tener en cuenta que los recursos de un equipo de `Ciencia de Datos` son limitados. Siempre estamos dispuestos a ofrecer nuestras habilidades, pero debemos ser eficientes en su uso. Es importante justificar la necesidad de involucrar al equipo de `Ciencia de Datos` en un proyecto en particular, en lugar de involucrarlos en todos los proyectos sin una justificación válida.

# %% [markdown]
# # ¿Cuál será el producto mínimo viable?

# %% [markdown]
# El Producto Mínimo Viable (PMV) es un prototipo de un producto o servicio que se lanzará, el cual cuenta con características mínimas que permiten presentarlo a clientes potenciales y comprobar su interés. El PMV proporciona un punto de entrada para el proyecto a todos los equipos involucrados, lo que facilita la tarea de escalar el producto desde allí de manera eficiente.

# %% [markdown]
# # ¿Cuándo se debe completar el proyecto?

# %% [markdown]
# Es fundamental para empezar a considerar qué opciones son factibles y cuáles no lo son, así como para establecer un objetivo claro. Si se decide que la idea del Producto Mínimo Viable (PMV) es viable, es importante definir cuándo se necesita completar el proyecto. Esto influirá en la asignación de recursos por parte de los líderes del equipo de `Ciencia de Datos`, quienes deberán tener en cuenta el plazo establecido para asegurarse de que los recursos estén disponibles para cumplir con el objetivo en el plazo deseado.

# %% [markdown]
# # ¿Hay alguna consideración en torno a la ética?

# %% [markdown]
# Debemos ser cada vez más conscientes de los permisos para acceder a ciertas fuentes de datos y de los sesgos que puedan existir en cualquier fuente. Si los datos históricos utilizados para entrenar nuestros modelos contienen sesgos ocultos, el modelo simplemente aprenderá y perpetuará esos patrones sesgados. Es fundamental evitar esta situación, por lo que es importante que esta cuestión sea abordada por el equipo de negocios lo antes posible.

# %% [markdown]
# # ¿Qué trabajo se ha hecho antes en esta área?

# %% [markdown]
# Es fundamental conocer el estado del arte y saber qué información o conocimiento tiene la empresa, y quién lo posee. Antes de empezar cualquier trabajo práctico, es importante hacer una exploración para determinar si alguien ya tiene ideas sobre lo que funciona y lo que no, qué datos existen y dónde se encuentran, o simplemente, algún conocimiento específico relacionado con la tarea en cuestión. Si encontramos esta información, podemos ahorrar semanas de trabajo y enfocar nuestros esfuerzos en áreas que aún necesitan ser exploradas.

# %% [markdown]
# # ¿En quién confiamos y quién confía en nosotros?

# %% [markdown]
# Es importante para entender quiénes más en el negocio estarán trabajando en este proyecto y en qué flujo general se encuentra nuestro equipo. Es necesario saber quién viene antes y después de nuestro equipo y en quiénes podemos confiar para comenzar nuestro trabajo, y quiénes confían en nosotros antes de que puedan comenzar el suyo. Debemos recordar que el equipo de `Ciencia de Datos` es solo una pieza del rompecabezas y que necesitamos trabajar de manera colaborativa con otros equipos para alcanzar los objetivos del proyecto.

# %% [markdown]
# # ¿Qué datos están disponibles, dónde están y en qué estado?

# %% [markdown]
# Para entender qué datos están disponibles, dónde se encuentran y en qué estado se encuentran, es importante hablar con otros en el negocio y tener una idea clara del tipo de datos que necesitamos. ¿Cuáles son los datos necesarios y cuáles de ellos están disponibles? ¿Hay fuentes de datos en otras partes del negocio que podrían ser útiles? Si hay datos cruciales obtenidos de una fuente externa, ¿dónde se pueden encontrar y cuánto trabajo será requerido para que sean utilizables? Estas preguntas son esenciales para poder obtener los datos necesarios para el proyecto y evaluar la calidad de los mismos.

# %% [markdown]
# # ¿Cuáles son los insights iniciales de la data?

# %% [markdown]
# Una de las primeras preguntas que debemos hacernos al analizar la data es "¿Cuál es el objetivo de negocio de este proyecto?" Es crucial estar alineado con este objetivo desde el principio y ajustar los plazos si es necesario. Los primeros insights de los datos son esenciales para entender el panorama general y ayudar a todas las partes interesadas a mantenerse involucradas en el proyecto y vigilar su desarrollo y progreso. Estos insights iniciales también pueden ser útiles para identificar patrones o tendencias importantes que puedan influir en la toma de decisiones.

# %% [markdown]
# # ¿Qué datos son valiosos, los podemos mejorar?

# %% [markdown]
# Después de explorar los `datos`, es importante identificar qué información es valiosa para el objetivo general del proyecto y cómo podemos mejorarla. En proyectos de `Machine Learning`, esto puede lograrse mediante la selección de variables relevantes, mientras que en la elaboración de un `dashboard`, podemos descartar información que no sea relevante para el objetivo clave en cuestión. En ambos casos, debemos asegurarnos de que los `datos` seleccionados sean de alta calidad y estén limpios para obtener insights precisos y significativos.

# %% [markdown]
# # ¿Qué enfoque y herramientas debemos usar? ¿Por qué?

# %% [markdown]
# Para garantizar que estamos utilizando las herramientas y enfoques adecuados, es esencial tener una comprensión clara de los `datos` disponibles y los objetivos del proyecto. Si estamos trabajando con `datos` no estructurados, por ejemplo, es posible que necesitemos considerar el uso de técnicas de procesamiento de `lenguaje natural` para extraer información útil. Además, podemos optar por un enfoque de `aprendizaje supervisado o no supervisado`, según la naturaleza del proyecto y los `datos`. Es importante seleccionar las herramientas y el enfoque adecuados en función de la tarea en cuestión y los `datos` disponibles, y no solo porque sean populares o estén de moda.

# %% [markdown]
# # ¿Cómo alinear los KPIs de `Ciencia de Datos` con los del negocio?

# %% [markdown]
# En la alineación de los KPIs de `Ciencia de Datos` con los del negocio, debemos considerar que los tomadores de decisiones pueden tener una visión diferente a la nuestra en cuanto a qué métricas son más importantes para el éxito del negocio. Por lo tanto, es fundamental que trabajemos con ellos para comprender sus objetivos clave y determinar cómo podemos ayudar a lograrlos con nuestras capacidades analíticas. En lugar de simplemente presentar nuestras propias métricas de `Ciencia de Datos`, debemos buscar entender las métricas clave del negocio y cómo se relacionan con nuestro trabajo. Esto nos permitirá proporcionar insights más valiosos y relevantes que puedan ser fácilmente interpretados y utilizados por los líderes del negocio.
